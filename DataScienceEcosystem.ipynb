# %% [markdown]
# # Data Science Tools

# %% [markdown]
# This notebook summarizes the tools and environments used in data science

# %% [markdown]
# **Objectives:**

# %% [markdown]
# + Learn about popular languages in data science.
# + Understand key libraries used by data scientists.
# + Explore important tools in the data science environment.

# %% [markdown]
# Common Programming Languages in Data Science:

# %% [markdown]
# 1. python
# 2. Ruby
# 3. Java

# %% [markdown]
# Popular Libraries:

# %% [markdown]
# 1. NumPy
# 2. Pandas
# 3. Matplotlib

# %% [markdown]
# | Data Science Tools |
# |--------------|
# | Jupyter Notebook |
# | RStudio |
# | Spyder  |

# %% [markdown]
# ### Examples of Evaluating Mathematical Expressions in Python:

# %%
# This is a simple arithmetic expression for multiplication followed by the addition of integers.
5 + ( 3*4 )
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60.

200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Hazem
