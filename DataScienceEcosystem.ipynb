# %% [markdown]
# # أدوات علم البيانات

# %% [markdown]
# في هذا الدفتر، يتم تلخيص أدوات وبيئة علم البيانات.

# %% [markdown]
# **الأهداف :**

# %% [markdown]
# + اللغات الشائعة لعلم البيانات
# + المكتبات الشائعة لعلم البيانات
# + أدوات علم البيانات

# %% [markdown]
#  : بعض اللغات الشائعة التي يستخدمها علماء البيانات هي

# %% [markdown]
# 1. python
# 2. Ruby
# 3. Java

# %% [markdown]
#  : بعض المكتبات الشائعة التي يستخدمها علماء البيانات تشمل

# %% [markdown]
# 1. NumPy
# 2. Pandas
# 3. Matplotlib

# %% [markdown]
# | أدوات علم البيانات |
# |--------------|
# | Jupyter Notebook |
# | RStudio |
# | Spyder  |

# %% [markdown]
# ### فيما يلي بعض الأمثلة على تقييم التعبيرات الحسابية في Python

# %%
# هذه تعبير حسابي بسيط لضرب ثم إضافة الأعداد الصحيحة
5 + ( 3*4 )
# Out:
# 17

# %%
# هذا سيحول 200 دقيقة إلى ساعات عن طريق القسمة على 60

200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## المؤلف
# حازم
